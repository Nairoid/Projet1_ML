# %%
import numpy as np
from scipy.stats.stats import pearsonr
from data import make_data1, make_data2
from plot import plot_boundary

from residual_fitting import *

#We create the dataset
X_train, y_train , X_test , y_test = make_data1(random_state=1) 

w = np.zeros(X_train.ndim+1)

residual_fitting.fit(w,X_train,y_train)

y_predict = residual_fitting.predict(w,X_test)

#for i in range(0,y_predict.shape[0]):
    #print(y_predict[i],y_test[i])
# Out:
# 0.48405709281752346 0
# 0.4845987122306726 0
# 0.4760219889271348 0
# 0.4465837827502452 1
# 0.4838296312729532 0
# 0.4836598825931829 0
# 0.47940635349655153 0
# 0.48309380899138143 0
# 0.4473716532490901 1
# 0.5171966742327582 1
# 0.4839808644025381 0
# 0.4503649378564641 1
# 0.4831063174364888 0
# 0.44851112945881033 1
# 0.4854168848304632 0
# 0.4676648366407119 1
# 0.48539120616296516 0
# 0.48450652167629044 0
# 0.4980746868225578 1
# 0.48273606390185303 0
# 0.48325425480668616 1
# 0.48148693970220857 0
# 0.48277340885381076 0
# 0.4838314005892648 0
# 0.4849819769591798 0
# 0.46960271339973925 1
# 0.45569673781504944 1
# 0.48840939116271764 0
# 0.48383070506595205 0
# 0.4998589546169025 1
# 0.4824161498422024 0
# 0.4840393040566996 0
# 0.509544625786702 1
# 0.48361131395538254 0
# 0.5260982994581994 1
# 0.4879915524595018 0
# 0.48197124847198214 0
# 0.49527814986138435 1
# 0.4865844820413168 0
# 0.484838079929498 0
# 0.4808659565874792 1
# 0.4839475855274368 0
# ...
